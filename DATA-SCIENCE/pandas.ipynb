# %%
import pandas as pd
import numpy as np

# %%
students = {
    'fname': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'lname': ['Smith', 'Johnson', 'Williams', 'Brown', 'Jones'],
    'age':[12,14,23,34,45],
    'average':[85, 90, 78, 92, 88]
}

# %%
df = pd.DataFrame(data=students)
df
# Out:
#      fname     lname  age  average
# 0    Alice     Smith   12       85
# 1      Bob   Johnson   14       90
# 2  Charlie  Williams   23       78
# 3    David     Brown   34       92
# 4      Eve     Jones   45       88

# %%
df.to_numpy()
# Out:
# array([['Alice', 'Smith', 12, 85],
#        ['Bob', 'Johnson', 14, 90],
#        ['Charlie', 'Williams', 23, 78],
#        ['David', 'Brown', 34, 92],
#        ['Eve', 'Jones', 45, 88]], dtype=object)

# %%
products = np.array([['sugar',450,10],
                     ['soap',800,12],
                     ['salt',300,8],
                     ['rice',500,15],
                     ['oil',600,20]])
products
# Out:
# array([['sugar', '450', '10'],
#        ['soap', '800', '12'],
#        ['salt', '300', '8'],
#        ['rice', '500', '15'],
#        ['oil', '600', '20']], dtype='<U21')

# %%
df2 = pd.DataFrame(data=products,columns=['name','price','quantity'])
df2
# Out:
#     name price quantity
# 0  sugar   450       10
# 1   soap   800       12
# 2   salt   300        8
# 3   rice   500       15
# 4    oil   600       20

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
pd  = pd.read_json('iris.json')
pd
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 0            5.1          3.5           1.4          0.2      Iris-setosa
# 1            4.9          3.0           1.4          0.2      Iris-setosa
# 2            4.7          3.2           1.3          0.2      Iris-setosa
# 3            4.6          3.1           1.5          0.2      Iris-setosa
# 4            5.0          3.6           1.4          0.2      Iris-setosa
# 5            5.4          3.9           1.7          0.4      Iris-setosa
# 6            4.6          3.4           1.4          0.3      Iris-setosa
# 7            5.0          3.4           1.5          0.2      Iris-setosa
# 8            4.4          2.9           1.4          0.2      Iris-setosa
# 9            4.9          3.1           1.5          0.1      Iris-setosa
# 10           5.4          3.7           1.5          0.2      Iris-setosa
# 11           4.8          3.4           1.6          0.2      Iris-setosa
# ...

# %%
# TODO: reading data  from msql database

# %%
# Methods of exproling data
# how can u now the number of rows and columns in the data frame

# df.shape
# df.tail()
# df.head()
# df.info()

# %%
df.shape
# Out:
# (150, 6)

# %%
 df.tail(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %%
 df.head(15)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
import pandas as pd

pd_titanic = pd.read_csv("titanic.csv")
pd_titanic
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
# 15          907         1       2
# 16          908         0       2
# 17          909         0       3
# 18          910         1       3
# 19          911         1       3
# 20          912         0       1
# 21          913         0       3
# 22          914         1       1
# 23          915         0       1
# 24          916         1       1
# 25          917         0       3
# ...

# %%
# reading column data
pd_titanic['Age']
# Out:
# 0     34.5
# 1     47.0
# 2     62.0
# 3     27.0
# 4     22.0
# 5     14.0
# 6     30.0
# 7     26.0
# 8     18.0
# 9     21.0
# 10     NaN
# 11    46.0
# 12    23.0
# 13    63.0
# 14    47.0
# 15    24.0
# 16    35.0
# 17    21.0
# 18    27.0
# 19    45.0
# 20    55.0
# 21     9.0
# 22     NaN
# 23    21.0
# 24    48.0
# 25    50.0
# 26    22.0
# 27    22.5
# 28    41.0
# 29     NaN
# 30    50.0
# 31    24.0
# 32    33.0
# 33     NaN
# 34    30.0
# 35    18.5
# 36     NaN
# 37    21.0
# 38    25.0
# 39     NaN
# 40    39.0
# 41     NaN
# 42    41.0
# 43    30.0
# 44    45.0
# Name: Age, dtype: float64

# %%
# get unique values in a column
pd_titanic['Age'].unique()
# Out:
# array([34.5, 47. , 62. , 27. , 22. , 14. , 30. , 26. , 18. , 21. ,  nan,
#        46. , 23. , 63. , 24. , 35. , 45. , 55. ,  9. , 48. , 50. , 22.5,
#        41. , 33. , 18.5, 25. , 39. ])

# %%
# TODO: loc and iloc

pd_titanic.iloc[:3, :3]
# Out:
#    PassengerId  Survived  Pclass
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2

# %%
# get the name and gender
pd_titanic.loc[:,'Name':'Sex']
# Out:
#                                                  Name     Sex
# 0                                    Kelly, Mr. James    male
# 1                    Wilkes, Mrs. James (Ellen Needs)  female
# 2                           Myles, Mr. Thomas Francis    male
# 3                                    Wirz, Mr. Albert    male
# 4        Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5                          Svensson, Mr. Johan Cervin    male
# 6                                Connolly, Miss. Kate  female
# 7                        Caldwell, Mr. Albert Francis    male
# 8           Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9                             Davies, Mr. John Samuel    male
# 10                                   Ilieff, Mr. Ylio    male
# 11                         Jones, Mr. Charles Cresson    male
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female
# 13                               Howard, Mr. Benjamin    male
# ...

# %%
# mean max median min :TODO

# %% [markdown]
# # DATA CLEANING(dropna)
# # dropna - drop the rows with missing values
# # fillna - fill the missing values with a specific value
# # duplicates - drop duplicates
# # notnull - check for non null values
# # isnull - check for null values
# # drop_duplicates - drop duplicates ,drops but does not return a new data frame. maintains the original data frame
# # duplicated - returns a boolean series indicating whether each row is a duplicate or not

# %%
# TODO: data transformation
